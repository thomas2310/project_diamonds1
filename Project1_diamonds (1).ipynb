# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %matplotlib inline

location = "diamonds.csv"
df = pd.read_csv(location, index_col=False)
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
df.set_index('Unnamed: 0',inplace=True)

# %%
df.head()
# Out:
#             carat      cut color clarity  depth  table  price     x     y  \
# Unnamed: 0
# 1            0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 2            0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 3            0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 4            0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 5            0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#                z
# Unnamed: 0
# 1           2.43
# 2           2.31
# 3           2.31
# 4           2.63
# 5           2.75

# %%
df = df.dropna()

# %%
df.head()
# Out:
#             carat      cut color clarity  depth  table  price     x     y  \
# Unnamed: 0
# 1            0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 2            0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 3            0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 4            0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 5            0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#                z
# Unnamed: 0
# 1           2.43
# 2           2.31
# 3           2.31
# 4           2.63
# 5           2.75

# %%
df.count()
# Out:
# carat      53940
# cut        53940
# color      53940
# clarity    53940
# depth      53940
# table      53940
# price      53940
# x          53940
# y          53940
# z          53940
# dtype: int64

# %%
len(df)
# Out:
# 53940

# %%
df['price'].min()
# Out:
# 326

# %%
df['price'].max()
# Out:
# 18823

# %%
df['price'].std()
# Out:
# 3989.4397381463023

# %%
df.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
dupe = df.drop_duplicates()
print(df.count())
dupe.count()
# Out:
# carat      53940
# cut        53940
# color      53940
# clarity    53940
# depth      53940
# table      53940
# price      53940
# x          53940
# y          53940
# z          53940
# dtype: int64
# carat      53794
# cut        53794
# color      53794
# clarity    53794
# depth      53794
# table      53794
# price      53794
# x          53794
# y          53794
# z          53794
# dtype: int64

# %%
dupe.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z'],
#       dtype='object')

# %%
corr = dupe.corr()
sns.heatmap(corr, vmin=-1, annot=True)

# %%
sns.countplot(x='color',
              data=df)

# %%
dupe = dupe.drop('table', axis=1)

# %%
dupe = dupe.drop('depth', axis=1)

# %%
dupe.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'price', 'x', 'y', 'z'], dtype='object')

# %%
dupe
# Out:
#             carat        cut color clarity  price     x     y     z
# Unnamed: 0
# 1            0.23      Ideal     E     SI2    326  3.95  3.98  2.43
# 2            0.21    Premium     E     SI1    326  3.89  3.84  2.31
# 3            0.23       Good     E     VS1    327  4.05  4.07  2.31
# 4            0.29    Premium     I     VS2    334  4.20  4.23  2.63
# 5            0.31       Good     J     SI2    335  4.34  4.35  2.75
# 6            0.24  Very Good     J    VVS2    336  3.94  3.96  2.48
# 7            0.24  Very Good     I    VVS1    336  3.95  3.98  2.47
# 8            0.26  Very Good     H     SI1    337  4.07  4.11  2.53
# 9            0.22       Fair     E     VS2    337  3.87  3.78  2.49
# 10           0.23  Very Good     H     VS1    338  4.00  4.05  2.39
# 11           0.30       Good     J     SI1    339  4.25  4.28  2.73
# 12           0.23      Ideal     J     VS1    340  3.93  3.90  2.46
# 13           0.22    Premium     F     SI1    342  3.88  3.84  2.33
# ...

# %%
dupe.sort_values('price', inplace=True)

# %%
dupe
# Out:
#             carat        cut color clarity  price     x     y     z
# Unnamed: 0
# 1            0.23      Ideal     E     SI2    326  3.95  3.98  2.43
# 2            0.21    Premium     E     SI1    326  3.89  3.84  2.31
# 3            0.23       Good     E     VS1    327  4.05  4.07  2.31
# 4            0.29    Premium     I     VS2    334  4.20  4.23  2.63
# 5            0.31       Good     J     SI2    335  4.34  4.35  2.75
# 6            0.24  Very Good     J    VVS2    336  3.94  3.96  2.48
# 7            0.24  Very Good     I    VVS1    336  3.95  3.98  2.47
# 8            0.26  Very Good     H     SI1    337  4.07  4.11  2.53
# 9            0.22       Fair     E     VS2    337  3.87  3.78  2.49
# 10           0.23  Very Good     H     VS1    338  4.00  4.05  2.39
# 11           0.30       Good     J     SI1    339  4.25  4.28  2.73
# 12           0.23      Ideal     J     VS1    340  3.93  3.90  2.46
# 13           0.22    Premium     F     SI1    342  3.88  3.84  2.33
# ...

# %%
pd.pivot_table(dupe, index=["color"])
# Out:
#           carat        price         x         y         z
# color
# D      0.658315  3174.441007  5.418634  5.422765  3.343698
# E      0.657957  3079.608020  5.411781  5.419299  3.340760
# F      0.736664  3726.749580  5.615836  5.620375  3.465005
# G      0.771273  4001.352069  5.677982  5.680691  3.505273
# H      0.911029  4482.855174  5.982574  5.984153  3.695279
# I      1.025197  5081.751248  6.219451  6.219482  3.843355
# J      1.162841  5326.415418  6.521021  6.519818  4.034265

# %%
writer = pd.ExcelWriter('DiamondsCleaned.xlsx', engine='xlsxwriter')
dupe.to_excel(writer, sheet_name='Sheet1')
writer.save()
